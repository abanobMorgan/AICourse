# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd 
import datetime

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data = pd.read_table("wind.data", sep = "\s+", parse_dates = [[0,1,2]]) 
data.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
data.Yr_Mo_Dy=data.Yr_Mo_Dy.apply(lambda x: f'{x.year -100 }-{x.month}-{x.day}')
data
# Out:
#         Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0       1961-1-1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1       1961-1-2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2       1961-1-3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3       1961-1-4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4       1961-1-5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1878-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  1878-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  1878-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  1878-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  1878-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# 2      8.50   7.67  12.75  12.71
# 3      5.83   5.88   5.46  10.88
# 4     10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...
# 6569  14.04  14.00  17.21  40.08
# 6570  15.25  18.05  21.79  41.46
# 6571  14.50  16.42  18.88  29.58
# 6572  12.46  12.12  14.67  28.79
# 6573  11.58  11.38  12.08  22.08
#
# [6574 rows x 13 columns]

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data["Yr_Mo_Dy"] = pd.to_datetime(data["Yr_Mo_Dy"])
data.set_index('Yr_Mo_Dy')
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1878-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1878-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1878-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1878-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1878-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83
# ...           ...    ...    ...
# 1878-12-27  14.00  17.21  40.08
# 1878-12-28  18.05  21.79  41.46
# 1878-12-29  16.42  18.88  29.58
# 1878-12-30  12.12  14.67  28.79
# 1878-12-31  11.38  12.08  22.08
#
# [6574 rows x 12 columns]

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isnull().sum()
# Out:
# Yr_Mo_Dy    0
# RPT         6
# VAL         3
# ROS         2
# KIL         5
# SHA         2
# BIR         0
# DUB         3
# CLA         2
# MUL         3
# CLO         1
# BEL         0
# MAL         4
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.shape[1] - data.isnull().sum()
# Out:
# Yr_Mo_Dy    13
# RPT          7
# VAL         10
# ROS         11
# KIL          8
# SHA         11
# BIR         13
# DUB         10
# CLA         11
# MUL         10
# CLO         12
# BEL         13
# MAL          9
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data.mean().mean()
# Out:
# 10.227982360836924

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
data.columns
# Out:
# Index(['Yr_Mo_Dy', 'RPT', 'VAL', 'ROS', 'KIL', 'SHA', 'BIR', 'DUB', 'CLA',
#        'MUL', 'CLO', 'BEL', 'MAL'],
#       dtype='object')

# %%
loc_stat = data.describe()
loc_stat.loc[['mean', 'std', 'max', 'min']]
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# mean  12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# std    5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
# max   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# min    0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# mean   9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# std    4.977555   4.499449   4.166872   4.503954   5.835037   6.699794
# max   30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# min    0.000000   0.000000   0.000000   0.040000   0.130000   0.670000

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats = pd.DataFrame()
day_stats['min'] = data.min(axis = 1) # min
day_stats['max'] = data.max(axis = 1) # max 
day_stats['mean'] = data.mean(axis = 1) # mean
day_stats['std'] = data.std(axis = 1) # standard deviations
day_stats.head()
# Out:
#     min    max       mean       std
# 0  9.29  18.50  13.018182  2.808875
# 1  6.50  17.54  11.336364  3.188994
# 2  6.17  18.50  11.641818  3.681912
# 3  1.79  11.75   6.619167  3.198126
# 4  6.17  13.33  10.630000  2.445356

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
data['month'] = data['Yr_Mo_Dy'].apply(lambda x: x.month)
data['year'] = data['Yr_Mo_Dy'].apply(lambda x: x.year)
data['day'] = data['Yr_Mo_Dy'].apply(lambda x: x.day)

# gets all value from the month 1 and assign to janyary_winds
january_winds = data.query('month == 1')

# gets the mean from january_winds, using .loc to not print the mean of month, year and day
january_winds.loc[:,'RPT':"MAL"].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
data.query('month == 1 and day == 1')
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
#
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6421 1878-08-01  19.33  15.09  20.17   8.83  12.62  10.41   9.33  12.33
# 6452 1878-09-01   8.42   6.13   9.87   5.25   3.21   5.71   7.25   3.50
# 6482 1878-10-01   9.50   6.83  10.50   3.88   6.13   4.58   4.21   6.50
# 6513 1878-11-01  13.59  16.75  11.25   7.08  11.04   8.33   8.17  11.29
# 6543 1878-12-01  21.29  16.29  24.04  12.79  18.21  19.29  21.54  17.21
#
#         MUL    CLO    BEL    MAL  month  year  day
# 0     10.83  12.58  18.50  15.04      1  1961    1
# 31     6.50   5.50   9.17   8.00      2  1961    1
# 59      NaN  12.21  20.62    NaN      3  1961    1
# 90    11.21   6.46  11.96   7.17      4  1961    1
# 120    9.75   9.92  18.63  11.12      5  1961    1
# ...     ...    ...    ...    ...    ...   ...  ...
# 6421   9.50   9.92  15.75  18.00      8  1878    1
# 6452   7.33   6.50   7.62  15.96      9  1878    1
# 6482   6.38   6.54  10.63  14.09     10  1878    1
# 6513  10.75  11.25  23.13  25.00     11  1878    1
# 6543  16.71  17.83  17.75  25.70     12  1878    1
#
# [216 rows x 16 columns]

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
data[::7]
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 7    1961-01-08  10.96   9.75   7.62   5.91   9.62   7.29  14.29   7.62
# 14   1961-01-15  12.04   9.67  11.75   2.37   7.38   3.13   2.50   6.83
# 21   1961-01-22   9.59   5.88   9.92   2.17   6.87   5.50   9.38   7.04
# 28   1961-01-29    NaN  23.91  22.29  17.54  24.08  19.70  22.00  20.25
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6545 1878-12-03  21.21  21.34  17.75  11.58  16.75  14.46  17.46  15.29
# 6552 1878-12-10  24.92  22.54  16.54  14.62  15.59  13.00  13.21  14.12
# 6559 1878-12-17   9.87   3.21   8.04   2.21   3.04   0.54   2.46   1.46
# 6566 1878-12-24   8.67   5.63  12.12   4.79   5.09   5.91  12.25   9.25
# 6573 1878-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL  month  year  day
# 0     10.83  12.58  18.50  15.04      1  1961    1
# 7      9.25  10.46  16.62  16.46      1  1961    8
# 14     4.75   5.63   7.54   6.75      1  1961   15
# 21     6.34   7.50  10.88   9.92      1  1961   22
# 28    21.46  19.95  27.71  23.38      1  1961   29
# ...     ...    ...    ...    ...    ...   ...  ...
# 6545  15.79  17.50  21.42  25.75     12  1878    3
# 6552  16.21  16.17  26.08  21.92     12  1878   10
# 6559   1.29   2.67   5.00   9.08     12  1878   17
# 6566  10.83  11.71  11.92  31.71     12  1878   24
# 6573  11.58  11.38  12.08  22.08     12  1878   31
#
# [940 rows x 16 columns]

# %% [markdown]
# ### Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
jun2 = data[1:365:7]
jun2.describe().loc[['min', 'max', 'mean', 'std']]
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# min    2.880000   3.040000   3.330000   1.460000   2.210000   0.830000
# max   24.500000  22.000000  32.710000  15.370000  25.330000  17.620000
# mean  12.150192   9.708627  11.799804   6.936078  10.711154   7.800192
# std    5.055704   4.675401   5.438290   3.664177   4.964523   3.999988
#
#             DUB        CLA        MUL        CLO        BEL        MAL  \
# min    1.250000   1.460000   2.210000   1.750000   5.040000   3.370000
# max   25.620000  18.790000  18.960000  17.920000  28.620000  26.300000
# mean  10.055192   9.042745   9.002115   9.897308  13.502500  14.020588
# std    5.526602   4.451634   4.289406   4.191501   6.030844   5.868595
#
#           month    year        day
# min    1.000000  1961.0   1.000000
# max   12.000000  1961.0  31.000000
# mean   6.442308  1961.0  15.769231
# std    3.477736     0.0   8.837566
